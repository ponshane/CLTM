# %%
import logging
import sys
sys.path.append('..')

from ptm import JointGibbsLDA, JointCorpus
from ptm.utils import get_top_words
from codebase.topic_evaluator import *

# %%
# prepare corpus
corpus = JointCorpus(source_corpus_file="../out/JointLDA_Inputs/50K_English_UM_Corpus.txt",
                     target_corpus_file="../out/JointLDA_Inputs/50K_Chinese_UM_Corpus.txt")

corpus.update_doctionary("../out/JointLDA_Inputs/um-corpus-news-top-translation.csv")

corpus.convert_raw_corpus_to_trainable_corpus()
# Out:
# 2019-01-14 18:12:45 INFO:JointCorpus:size of concept: 2720, size of source vocab: 9695, size of target vocab: 18449
# 2019-01-14 18:12:45 INFO:JointCorpus:Successfully generate idx corpus 'self.docs' and language flags 'self.language_flags'

# %%
# train model
n_topic=20
model = JointGibbsLDA(n_doc=len(corpus.docs), n_concept=corpus.n_concept, n_s_vocab=corpus.n_s_vocab,
                      n_t_vocab=corpus.n_t_vocab, n_topic=n_topic)
model.fit(corpus.docs, corpus.language_flags, max_iter=100)
# Out:
# 2019-01-14 18:12:52 INFO:JointGibbsLDA:[ITER] 0,	elapsed time:2.86,	log_likelihood:-3658856.63
# 2019-01-14 18:12:55 INFO:JointGibbsLDA:[ITER] 1,	elapsed time:3.04,	log_likelihood:-3468978.38
# 2019-01-14 18:12:58 INFO:JointGibbsLDA:[ITER] 2,	elapsed time:3.08,	log_likelihood:-3375433.12
# 2019-01-14 18:13:01 INFO:JointGibbsLDA:[ITER] 3,	elapsed time:3.11,	log_likelihood:-3315378.07
# 2019-01-14 18:13:04 INFO:JointGibbsLDA:[ITER] 4,	elapsed time:3.25,	log_likelihood:-3272095.78
# 2019-01-14 18:13:08 INFO:JointGibbsLDA:[ITER] 5,	elapsed time:3.26,	log_likelihood:-3234532.18
# 2019-01-14 18:13:11 INFO:JointGibbsLDA:[ITER] 6,	elapsed time:3.50,	log_likelihood:-3205299.62
# 2019-01-14 18:13:14 INFO:JointGibbsLDA:[ITER] 7,	elapsed time:3.29,	log_likelihood:-3181762.67
# 2019-01-14 18:13:17 INFO:JointGibbsLDA:[ITER] 8,	elapsed time:3.46,	log_likelihood:-3159860.80
# 2019-01-14 18:13:21 INFO:JointGibbsLDA:[ITER] 9,	elapsed time:3.19,	log_likelihood:-3139396.37
# 2019-01-14 18:13:24 INFO:JointGibbsLDA:[ITER] 10,	elapsed time:3.04,	log_likelihood:-3122010.29
# 2019-01-14 18:13:27 INFO:JointGibbsLDA:[ITER] 11,	elapsed time:3.05,	log_likelihood:-3106564.74
# 2019-01-14 18:13:30 INFO:JointGibbsLDA:[ITER] 12,	elapsed time:3.20,	log_likelihood:-3094034.23
# 2019-01-14 18:13:33 INFO:JointGibbsLDA:[ITER] 13,	elapsed time:3.25,	log_likelihood:-3081453.62
# 2019-01-14 18:13:36 INFO:JointGibbsLDA:[ITER] 14,	elapsed time:3.14,	log_likelihood:-3071603.11
# 2019-01-14 18:13:40 INFO:JointGibbsLDA:[ITER] 15,	elapsed time:2.98,	log_likelihood:-3061271.84
# 2019-01-14 18:13:43 INFO:JointGibbsLDA:[ITER] 16,	elapsed time:3.10,	log_likelihood:-3052815.39
# 2019-01-14 18:13:46 INFO:JointGibbsLDA:[ITER] 17,	elapsed time:3.13,	log_likelihood:-3044907.82
# 2019-01-14 18:13:49 INFO:JointGibbsLDA:[ITER] 18,	elapsed time:3.20,	log_likelihood:-3034323.92
# 2019-01-14 18:13:52 INFO:JointGibbsLDA:[ITER] 19,	elapsed time:3.44,	log_likelihood:-3026578.17
# 2019-01-14 18:13:56 INFO:JointGibbsLDA:[ITER] 20,	elapsed time:3.59,	log_likelihood:-3020973.11
# 2019-01-14 18:13:59 INFO:JointGibbsLDA:[ITER] 21,	elapsed time:3.21,	log_likelihood:-3013991.57
# 2019-01-14 18:14:02 INFO:JointGibbsLDA:[ITER] 22,	elapsed time:3.52,	log_likelihood:-3008690.13
# 2019-01-14 18:14:06 INFO:JointGibbsLDA:[ITER] 23,	elapsed time:3.35,	log_likelihood:-3001771.14
# 2019-01-14 18:14:09 INFO:JointGibbsLDA:[ITER] 24,	elapsed time:3.11,	log_likelihood:-2995829.88
# 2019-01-14 18:14:12 INFO:JointGibbsLDA:[ITER] 25,	elapsed time:3.02,	log_likelihood:-2991439.31
# 2019-01-14 18:14:15 INFO:JointGibbsLDA:[ITER] 26,	elapsed time:3.24,	log_likelihood:-2987139.29
# 2019-01-14 18:14:18 INFO:JointGibbsLDA:[ITER] 27,	elapsed time:2.97,	log_likelihood:-2982141.51
# 2019-01-14 18:14:21 INFO:JointGibbsLDA:[ITER] 28,	elapsed time:3.34,	log_likelihood:-2976969.03
# 2019-01-14 18:14:25 INFO:JointGibbsLDA:[ITER] 29,	elapsed time:3.32,	log_likelihood:-2974800.91
# 2019-01-14 18:14:28 INFO:JointGibbsLDA:[ITER] 30,	elapsed time:3.38,	log_likelihood:-2970821.90
# 2019-01-14 18:14:31 INFO:JointGibbsLDA:[ITER] 31,	elapsed time:3.33,	log_likelihood:-2966474.19
# 2019-01-14 18:14:34 INFO:JointGibbsLDA:[ITER] 32,	elapsed time:3.26,	log_likelihood:-2962956.18
# 2019-01-14 18:14:38 INFO:JointGibbsLDA:[ITER] 33,	elapsed time:3.39,	log_likelihood:-2958927.50
# 2019-01-14 18:14:41 INFO:JointGibbsLDA:[ITER] 34,	elapsed time:3.01,	log_likelihood:-2955535.00
# 2019-01-14 18:14:44 INFO:JointGibbsLDA:[ITER] 35,	elapsed time:3.29,	log_likelihood:-2951844.19
# 2019-01-14 18:14:47 INFO:JointGibbsLDA:[ITER] 36,	elapsed time:3.09,	log_likelihood:-2949044.73
# 2019-01-14 18:14:50 INFO:JointGibbsLDA:[ITER] 37,	elapsed time:3.27,	log_likelihood:-2945843.59
# 2019-01-14 18:14:53 INFO:JointGibbsLDA:[ITER] 38,	elapsed time:2.96,	log_likelihood:-2943819.85
# 2019-01-14 18:14:57 INFO:JointGibbsLDA:[ITER] 39,	elapsed time:3.24,	log_likelihood:-2942046.37
# 2019-01-14 18:15:00 INFO:JointGibbsLDA:[ITER] 40,	elapsed time:3.28,	log_likelihood:-2939168.85
# 2019-01-14 18:15:03 INFO:JointGibbsLDA:[ITER] 41,	elapsed time:3.28,	log_likelihood:-2936639.25
# 2019-01-14 18:15:06 INFO:JointGibbsLDA:[ITER] 42,	elapsed time:3.06,	log_likelihood:-2933820.70
# 2019-01-14 18:15:10 INFO:JointGibbsLDA:[ITER] 43,	elapsed time:3.58,	log_likelihood:-2931622.29
# 2019-01-14 18:15:13 INFO:JointGibbsLDA:[ITER] 44,	elapsed time:3.28,	log_likelihood:-2928987.34
# 2019-01-14 18:15:16 INFO:JointGibbsLDA:[ITER] 45,	elapsed time:3.01,	log_likelihood:-2927674.56
# 2019-01-14 18:15:19 INFO:JointGibbsLDA:[ITER] 46,	elapsed time:3.15,	log_likelihood:-2926043.15
# 2019-01-14 18:15:22 INFO:JointGibbsLDA:[ITER] 47,	elapsed time:3.00,	log_likelihood:-2923288.90
# 2019-01-14 18:15:25 INFO:JointGibbsLDA:[ITER] 48,	elapsed time:3.00,	log_likelihood:-2922690.14
# 2019-01-14 18:15:29 INFO:JointGibbsLDA:[ITER] 49,	elapsed time:3.18,	log_likelihood:-2919729.85
# 2019-01-14 18:15:32 INFO:JointGibbsLDA:[ITER] 50,	elapsed time:3.23,	log_likelihood:-2919358.44
# 2019-01-14 18:15:35 INFO:JointGibbsLDA:[ITER] 51,	elapsed time:3.47,	log_likelihood:-2917632.11
# 2019-01-14 18:15:39 INFO:JointGibbsLDA:[ITER] 52,	elapsed time:3.60,	log_likelihood:-2916238.95
# 2019-01-14 18:15:42 INFO:JointGibbsLDA:[ITER] 53,	elapsed time:3.06,	log_likelihood:-2914728.28
# 2019-01-14 18:15:45 INFO:JointGibbsLDA:[ITER] 54,	elapsed time:3.29,	log_likelihood:-2912900.82
# 2019-01-14 18:15:49 INFO:JointGibbsLDA:[ITER] 55,	elapsed time:3.24,	log_likelihood:-2911840.35
# 2019-01-14 18:15:52 INFO:JointGibbsLDA:[ITER] 56,	elapsed time:3.27,	log_likelihood:-2910256.21
# 2019-01-14 18:15:55 INFO:JointGibbsLDA:[ITER] 57,	elapsed time:3.19,	log_likelihood:-2910487.74
# 2019-01-14 18:15:58 INFO:JointGibbsLDA:[ITER] 58,	elapsed time:3.24,	log_likelihood:-2907533.46
# 2019-01-14 18:16:02 INFO:JointGibbsLDA:[ITER] 59,	elapsed time:3.21,	log_likelihood:-2906662.59
# 2019-01-14 18:16:05 INFO:JointGibbsLDA:[ITER] 60,	elapsed time:3.32,	log_likelihood:-2904950.89
# 2019-01-14 18:16:08 INFO:JointGibbsLDA:[ITER] 61,	elapsed time:3.41,	log_likelihood:-2903410.48
# 2019-01-14 18:16:12 INFO:JointGibbsLDA:[ITER] 62,	elapsed time:3.28,	log_likelihood:-2902221.77
# 2019-01-14 18:16:15 INFO:JointGibbsLDA:[ITER] 63,	elapsed time:2.95,	log_likelihood:-2900050.15
# 2019-01-14 18:16:18 INFO:JointGibbsLDA:[ITER] 64,	elapsed time:3.17,	log_likelihood:-2899601.85
# 2019-01-14 18:16:21 INFO:JointGibbsLDA:[ITER] 65,	elapsed time:3.01,	log_likelihood:-2897711.37
# 2019-01-14 18:16:24 INFO:JointGibbsLDA:[ITER] 66,	elapsed time:2.99,	log_likelihood:-2896788.69
# 2019-01-14 18:16:27 INFO:JointGibbsLDA:[ITER] 67,	elapsed time:3.00,	log_likelihood:-2896853.94
# 2019-01-14 18:16:31 INFO:JointGibbsLDA:[ITER] 68,	elapsed time:3.79,	log_likelihood:-2896831.73
# 2019-01-14 18:16:34 INFO:JointGibbsLDA:[ITER] 69,	elapsed time:3.22,	log_likelihood:-2894423.44
# 2019-01-14 18:16:37 INFO:JointGibbsLDA:[ITER] 70,	elapsed time:3.46,	log_likelihood:-2892920.94
# 2019-01-14 18:16:41 INFO:JointGibbsLDA:[ITER] 71,	elapsed time:3.30,	log_likelihood:-2893390.34
# 2019-01-14 18:16:44 INFO:JointGibbsLDA:[ITER] 72,	elapsed time:3.15,	log_likelihood:-2891754.96
# 2019-01-14 18:16:47 INFO:JointGibbsLDA:[ITER] 73,	elapsed time:3.31,	log_likelihood:-2890811.98
# 2019-01-14 18:16:50 INFO:JointGibbsLDA:[ITER] 74,	elapsed time:2.93,	log_likelihood:-2890142.51
# 2019-01-14 18:16:54 INFO:JointGibbsLDA:[ITER] 75,	elapsed time:3.28,	log_likelihood:-2889724.20
# 2019-01-14 18:16:57 INFO:JointGibbsLDA:[ITER] 76,	elapsed time:3.07,	log_likelihood:-2889084.71
# 2019-01-14 18:17:00 INFO:JointGibbsLDA:[ITER] 77,	elapsed time:3.21,	log_likelihood:-2887291.23
# 2019-01-14 18:17:03 INFO:JointGibbsLDA:[ITER] 78,	elapsed time:3.08,	log_likelihood:-2887914.93
# 2019-01-14 18:17:07 INFO:JointGibbsLDA:[ITER] 79,	elapsed time:3.39,	log_likelihood:-2886286.09
# 2019-01-14 18:17:10 INFO:JointGibbsLDA:[ITER] 80,	elapsed time:3.02,	log_likelihood:-2884367.25
# 2019-01-14 18:17:13 INFO:JointGibbsLDA:[ITER] 81,	elapsed time:3.28,	log_likelihood:-2883913.64
# 2019-01-14 18:17:16 INFO:JointGibbsLDA:[ITER] 82,	elapsed time:3.31,	log_likelihood:-2884070.50
# 2019-01-14 18:17:19 INFO:JointGibbsLDA:[ITER] 83,	elapsed time:3.07,	log_likelihood:-2883610.70
# 2019-01-14 18:17:22 INFO:JointGibbsLDA:[ITER] 84,	elapsed time:3.07,	log_likelihood:-2882749.04
# 2019-01-14 18:17:26 INFO:JointGibbsLDA:[ITER] 85,	elapsed time:3.43,	log_likelihood:-2881544.62
# 2019-01-14 18:17:29 INFO:JointGibbsLDA:[ITER] 86,	elapsed time:3.14,	log_likelihood:-2880820.95
# 2019-01-14 18:17:32 INFO:JointGibbsLDA:[ITER] 87,	elapsed time:3.11,	log_likelihood:-2880213.82
# 2019-01-14 18:17:35 INFO:JointGibbsLDA:[ITER] 88,	elapsed time:3.30,	log_likelihood:-2879242.91
# 2019-01-14 18:17:39 INFO:JointGibbsLDA:[ITER] 89,	elapsed time:3.29,	log_likelihood:-2879116.92
# 2019-01-14 18:17:42 INFO:JointGibbsLDA:[ITER] 90,	elapsed time:3.38,	log_likelihood:-2877833.13
# 2019-01-14 18:17:45 INFO:JointGibbsLDA:[ITER] 91,	elapsed time:3.20,	log_likelihood:-2876502.73
# 2019-01-14 18:17:48 INFO:JointGibbsLDA:[ITER] 92,	elapsed time:3.29,	log_likelihood:-2876157.96
# 2019-01-14 18:17:52 INFO:JointGibbsLDA:[ITER] 93,	elapsed time:3.28,	log_likelihood:-2875538.93
# 2019-01-14 18:17:55 INFO:JointGibbsLDA:[ITER] 94,	elapsed time:3.50,	log_likelihood:-2874904.55
# 2019-01-14 18:17:58 INFO:JointGibbsLDA:[ITER] 95,	elapsed time:3.22,	log_likelihood:-2875361.74
# 2019-01-14 18:18:01 INFO:JointGibbsLDA:[ITER] 96,	elapsed time:3.29,	log_likelihood:-2874328.43
# 2019-01-14 18:18:05 INFO:JointGibbsLDA:[ITER] 97,	elapsed time:3.50,	log_likelihood:-2873725.87
# 2019-01-14 18:18:08 INFO:JointGibbsLDA:[ITER] 98,	elapsed time:2.97,	log_likelihood:-2872780.84
# 2019-01-14 18:18:11 INFO:JointGibbsLDA:[ITER] 99,	elapsed time:3.00,	log_likelihood:-2870918.44

# %%
# show top words
for ti in range(n_topic):
    top_words = get_top_words(model.TW, corpus.reconcatenate_dict, ti, n_words=50)
    print('Topic', ti ,': ', top_words)
    #print('Topic', ti ,': ', ','.join(top_words))
# Out:
# Topic 0 :  [('year', '年度') ('world', '世界') 'percent' ('food', '食物') '可以' 'billion'
#  ('people', '人们') 'million' ('school', '学校') ('bank', '银行') '时候' '没有'
#  ('child', '孩子') ('economy', '经济体') ('america', '全美') ('group', '集团') '一起'
#  '这样' '可能' 'half' ('japan', '日本') ('happening', '情况') '这种' '表示'
#  ('china', '中国') ('plant', '植物') ('tax', '税收') ('like', '喜欢') 'high'
#  ('budget', '预算') ('participate', '参加') ('planting', '种植') ('life', '生活')
#  'thousand' '有些' 'seven' ('rate', '房价') ('party', '派对') '不能'
#  ('student', '学生') ('protection', '保护') ('think', '认为') '看到'
#  ('suggest', '建议') ('development', '开发') '一种' ('marry', '结婚')
#  ('united', '团结') ('growth', '增长速度') 'cut']
# Topic 1 :  [('people', '人们') '工作' '美国' ('student', '学生') '大学' ('obtain', '获得')
#  ('men', '男士') ('water', '水中') ('project', '项目') '公司' ('work', '做事')
#  'found' ('provide', '提供') ('need', '需要') ('way', '途径') '通过'
#  ('team', '团队') ('time', '时间') '得到' 'ice' ('hope', '希望') ('use', '使用')
#  ('data', '数据') '亿美元' '申请' ('future', '未来') '可以' ('investment', '投资') '资金'
#  ('place', '场所') ('pay', '支付') ('professor', '教授') '不能' '必须'
#  ('education', '教育') ('cold', '寒冷') ('technology', '技术') ('black', '黑色')
#  ('school', '学校') ('sea', '海域') ('live', '居住') 'taking' 'dr'
#  ('point', '要点') ('average', '平均水平') 'high' ('government', '政府')
#  ('idea', '想法') 'lot' '现在']
# Topic 2 :  ['美国' ('people', '人们') ('president', '总统') ('national', '全国') '支持'
#  ('female', '女性') ('marriage', '婚姻') ('think', '认为') ('united', '团结')
#  'american' ('country', '国家') ('year', '年度') ('obama', '奥巴马') '成为' '重要'
#  '政治' ('man', '男子') ('life', '生活') ('faith', '信仰') '表示' ('family', '家庭')
#  '一位' ('republican', '共和党') ('candidate', '候选人') ('hope', '希望')
#  ('park', '公园') ('voter', '选民') ('male', '男性') ('live', '居住') 'americans'
#  ('kennedy', '肯尼迪') ('world', '世界') ('society', '社会') ('steve', '史蒂夫')
#  '竞选' ('child', '孩子') ('obtain', '获得') 'thousand' ('war', '战争') '可能'
#  ('century', '世纪') ('health', '健康') ('religion', '宗教') ('romney', '罗姆尼')
#  ('care', '在乎') '得到' ('senator', '参议员') ('race', '种族') ('woman', '女人')
#  ('democrats', '民主党')]
# Topic 3 :  ['美国' ('country', '国家') ('time', '时间') ('help', '帮助') '增加' ('need', '需要')
#  ('immigration', '移民') ('let', '就让') '减少' ('mechanism', '机构')
#  ('disease', '疾病') ('area', '地区') ('china', '中国') '全球' ('report', '报告')
#  ('provide', '提供') 'found' 'human' ('world', '世界') ('speed', '速度')
#  ('africa', '非洲') ('project', '项目') ('plan', '计划') '来自' 'high'
#  ('decline', '下降') ('government', '政府') ('oil', '石油') ('listen', '倾听')
#  '联合国' 'dr' '表示' ('blood', '血液') ('light', '光线') '不断' ('assistance', '援助')
#  ('paper', '论文') ('international', '国际') '发展' ('quantity', '数量')
#  ('ability', '能力') ('start', '开始') ('tax', '税收') ('green', '绿色') '同时'
#  ('cooperation', '合作') ('test', '测试') ('europe', '欧洲') ('treatment', '治疗')
#  ('drug', '药物')]
# Topic 4 :  ['一个' ('like', '喜欢') ('food', '食物') ('people', '人们') ('local', '地方')
#  ('water', '水中') '这样' '可能' ('start', '开始') '不同' '一样' '出来' ('feel', '感到')
#  ('eat', '吃饭') '时候' '可以' ('good', '良好') ('life', '生活') ('digital', '数字')
#  ('plastic', '塑料') ('hope', '希望') ('kind', '亲切') ('way', '途径')
#  ('young', '年轻') '出生' ('means', '手段') ('think', '认为') ('inside', '里面')
#  ('idea', '想法') ('girl', '女孩') ('woman', '女人') ('newspaper', '报纸')
#  ('news', '新闻') ('stay', '留下') '其中' ('compare', '比较') ('party', '派对')
#  ('appear', '出现') ('table', '桌子') ('long', '长期') ('century', '世纪')
#  ('family', '家庭') ('come', '来到') '这种' ('weight', '重量') 'job'
#  ('song', '歌曲') ('fat', '脂肪') ('meat', '肉类') ('low', '低下')]
# Topic 5 :  [('aircraft', '飞机') ('obama', '奥巴马') ('need', '需要') ('president', '总统')
#  ('provide', '提供') ('mr', '先生') '方式' '可以' '这种' '一种' ('sound', '声音')
#  ('country', '国家') ('iran', '伊朗') ('help', '帮助') ('use', '使用') '能够'
#  ('university', '高校') ('united', '团结') 'state' ('think', '认为') 'nuclear'
#  ('service', '服务') ('issue', '发出') ('future', '未来') '没有' '目标' '可能'
#  ('world', '世界') ('system', '系统') '必须' ('way', '途径') ('run', '运行')
#  ('general', '将军') ('clear', '清楚') '这样' ('airport', '机场') 'term'
#  ('romney', '罗姆尼') ('election', '选举') 'barack' ('washington', '华盛顿')
#  ('year', '年度') ('government', '政府') 'campaign' '为了' '如何' '决定'
#  ('reaction', '反应') '进行' ('party', '派对')]
# Topic 6 :  ['节目' ('going', '走向') '美国' '今天' ('english', '英语') '本期' '收听'
#  ('welcome', '欢迎') ('like', '喜欢') ('think', '认为') '慢速' ('game', '比赛')
#  ('tell', '告诉') ('want', '想要') ('know', '知道') ('music', '音乐')
#  ('today', '当今') ('song', '歌曲') ('expression', '表达') ('culture', '文化')
#  ('talk', '谈论') ('time', '时间') ('people', '人们') ('means', '手段')
#  ('podcast', '播客') ('watch', '观看') ('play', '发挥') ('story', '故事') '一个'
#  ('start', '开始') ('vocabulary', '词汇') ('football', '足球') ('city', '城市')
#  ('answer', '答案') ('come', '来到') ('thanksgiving', '感恩节') '所有'
#  ('day', '日子') ('right', '权利') '美国之音' ('good', '良好') ('way', '途径')
#  ('coffee', '咖啡') '时候' ('topic', '话题') '没有' '继续' ('william', '威廉')
#  ('question', '质疑') '最后']
# Topic 7 :  ['公司' ('technology', '技术') ('enterprise', '企业') ('computer', '电脑')
#  ('apple', '苹果') ('world', '世界') ('software', '软件') '一家' ('mr', '先生')
#  ('product', '产品') ('system', '系统') ('internet', '上网') ('google', '谷歌')
#  ('mobile', '移动') ('business', '业务') ('market', '市场') ('social', '社交')
#  ('firm', '事务所') ('online', '网上') ('phone', '手机') ('industry', '行业')
#  ('media', '媒体') ('information', '信息') '亿美元' ('investment', '投资')
#  ('russia', '俄罗斯') ('user', '用户') ('year', '年度') ('data', '数据')
#  ('service', '服务') ('investor', '投资者') ('price', '价格') '一个' ('plan', '计划')
#  ('boss', '老板') ('car', '汽车') ('equipment', '设备') ('patent', '专利')
#  ('value', '价值') ('success', '成功') ('profit', '利润') ('microsoft', '微软')
#  ('transaction', '交易') '通过' ('news', '新闻') ('provide', '提供')
#  ('research', '科研') ('acquisition', '收购') ('produce', '生产')
#  ('giant', '巨头')]
# Topic 8 :  [('time', '时间') ('work', '做事') ('going', '走向') ('want', '想要')
#  ('means', '手段') '表示' ('need', '需要') ('good', '良好') ('person', '人士')
#  ('school', '学校') '法律' ('leave', '留给') ('tell', '告诉') ('house', '房子')
#  ('home', '家里') 'talking' 'saying' '一个' ('like', '喜欢') ('example', '例子')
#  ('mean', '意味着') '原因' '是否' '有关' ('start', '开始') '必须' ('come', '来到')
#  ('stop', '停止') ('way', '途径') ('place', '场所') '主要' 'hard' ('claim', '要求')
#  ('mother', '母亲') 'job' ('government', '政府') '指控' ('lawyer', '律师')
#  ('court', '法庭') ('coffee', '咖啡') ('kind', '亲切') '审判' '决定' ('judge', '法官')
#  ('survey', '调查') ('people', '人们') '说道' ('travel', '旅行') ('meaning', '意思')
#  '美国']
# Topic 9 :  [('money', '金钱') ('people', '人们') ('organization', '组织') 'company'
#  ('pay', '支付') ('attack', '袭击') ('occur', '发生') ('going', '走向')
#  ('business', '业务') '美国' ('activity', '活动') ('buy', '购买') ('means', '手段')
#  '一名' ('army', '军队') ('syria', '叙利亚') ('use', '使用') ('event', '事件')
#  ('price', '价格') ('government', '政府') '警察' ('like', '喜欢') 'lot'
#  ('sell', '出售') ('area', '地区') ('protest', '抗议') ('war', '战争')
#  ('death', '死亡') ('libya', '利比亚') ('cost', '费用') ('time', '时间') '抗议者' '报道'
#  ('violence', '暴力') ('long', '长期') ('card', '卡片') ('egypt', '埃及')
#  ('capital', '首都') ('store', '商店') ('think', '认为') '伊斯兰' ('spend', '花费')
#  ('base', '基地') ('way', '途径') ('kenya', '肯尼亚') ('service', '服务')
#  ('somalia', '索马里') ('product', '产品') ('country', '国家') ('police', '警方')]
# Topic 10 :  ['一个' ('park', '公园') ('space', '空间') ('like', '喜欢') ('local', '地方')
#  ('country', '国家') ('book', '本书') '工作' ('city', '城市') '纽约' 'television'
#  'old' ('think', '认为') ('east', '东部') ('way', '途径') ('street', '街道')
#  ('time', '时间') 'away' ('film', '影片') '能够' ('worker', '工人') ('year', '年度')
#  ('enter', '进入') '两个' '为了' ('radio', '电台') ('earth', '地球') 'middle' '一位'
#  '游客' ('museum', '博物馆') ('snow', '斯诺') ('end', '结束') 'movie'
#  ('train', '火车') ('union', '工会') ('ms', '女士') '成为' ('member', '成员') '表演'
#  '一起' '当地' ('institute', '研究院') ('factory', '工厂') '称为' ('research', '科研')
#  '博士' ('class', '上课') '位于' ('production', '制作')]
# Topic 11 :  [('problem', '问题') ('think', '认为') ('country', '国家') ('car', '汽车')
#  ('information', '信息') 'company' '可能' '没有' '一个' ('people', '人们')
#  ('oil', '石油') 'american' ('project', '项目') '这种' ('power', '力量') '变得'
#  ('behavior', '行为') ('energy', '能源') '受到' ('aircraft', '飞机')
#  ('flight', '航班') ('view', '观点') '美国' '进行' ('include', '包括')
#  ('need', '需要') '影响' ('public', '公众') ('protection', '保护') ('use', '使用')
#  '应该' ('find', '发现') '其中' ('world', '世界') ('help', '帮助') 'agency'
#  ('industry', '行业') ('plane', '架飞机') ('allow', '允许') '作为' ('china', '中国')
#  ('challenge', '挑战') ('robot', '机器人') ('land', '土地') ('social', '社交') '可以'
#  '威胁' '所有' ('society', '社会') ('exist', '存在')]
# Topic 12 :  ['工作' ('people', '人们') ('special', '特殊') ('english', '英语')
#  ('meaning', '意思') '没有' ('report', '报告') '一个' '这样' ('health', '健康') 'voa'
#  ('thing', '事情') ('know', '知道') ('university', '高校') '可能' ('school', '学校')
#  ('child', '孩子') ('news', '新闻') ('need', '需要') '电影' ('change', '改变')
#  ('program', '方案') '觉得' ('week', '星期') ('world', '世界') ('year', '年度')
#  'study' ('time', '时间') '可以' ('friend', '朋友') ('employee', '员工')
#  ('tell', '告诉') ('problem', '问题') ('education', '教育') '应该'
#  ('climate', '气候') ('organization', '组织') '一位' ('care', '在乎')
#  ('young', '年轻') 'american' ('help', '帮助') ('success', '成功')
#  ('long', '长期') ('boss', '老板') '不想' ('professor', '教授') '努力'
#  ('start', '开始') ('america', '全美')]
# Topic 13 :  [('president', '总统') ('government', '政府') '美国' ('obama', '奥巴马')
#  ('mr', '先生') ('leader', '领导人') ('north', '北部') ('congress', '国会')
#  ('iran', '伊朗') ('afghanistan', '阿富汗') 'state' ('south', '南部')
#  ('war', '战争') ('country', '国家') ('united', '团结') ('end', '结束')
#  ('korea', '韩国') '进行' '表示' '支持' ('meeting', '会议') ('pakistan', '巴基斯坦')
#  '通过' '联合国' ('committee', '委员会') ('china', '中国') ('bill', '法案')
#  ('nixon', '尼克松') ('claim', '要求') ('america', '全美') ('syria', '叙利亚')
#  ('senate', '参议院') ('policy', '政策') '总理' ('international', '国际')
#  ('oppose', '反对') ('protocol', '协议') ('hold', '举行') ('house', '房子')
#  ('election', '选举') ('vote', '投票') ('problem', '问题') '发表'
#  ('washington', '华盛顿') ('military', '军事') ('johnson', '约翰逊')
#  ('speech', '演讲') ('support', '支撑') ('month', '月份') ('plan', '计划')]
# Topic 14 :  [('city', '城市') ('people', '人们') ('area', '地区') '美国' ('government', '政府')
#  ('capital', '首都') '一个' ('south', '南部') ('washington', '华盛顿')
#  ('attack', '袭击') ('russia', '俄罗斯') ('united', '团结') ('group', '集团')
#  'york' ('town', '城镇') ('time', '时间') ('start', '开始') ('police', '警方')
#  'state' 'al' ('fighting', '战斗') ('local', '地方') ('occur', '发生') 'un'
#  ('ukraine', '乌克兰') ('sudan', '苏丹') ('war', '战争') ('find', '发现')
#  ('army', '军队') ('week', '星期') ('left', '剩下') ('military', '军事') 'anti'
#  ('violence', '暴力') ('general', '将军') ('friday', '周五') ('mexico', '墨西哥')
#  ('headquarters', '总部') '进行' ('central', '中央') ('key', '钥匙')
#  ('revolution', '革命') ('personnel', '人员') ('international', '国际')
#  ('near', '靠近') ('west', '西方') '现在' 'american' ('houston', '休斯顿')
#  ('safety', '安全')]
# Topic 15 :  ['研究' ('find', '发现') '这种' ('government', '政府') '进行' ('result', '结果')
#  ('gene', '基因') '一种' '影响' '博士' ('personnel', '人员') ('security', '保安')
#  ('treatment', '治疗') ('method', '方法') ('disease', '疾病') ('humanity', '人类')
#  '表明' '可能' ('experiment', '实验') ('cell', '细胞') '科学家'
#  ('international', '国际') ('report', '报告') ('patient', '患者')
#  ('problem', '问题') '通过' ('risk', '风险') '一项' '表示' ('council', '理事会')
#  ('health', '健康') ('think', '认为') ('drug', '药物') '产生' '导致'
#  ('opposition', '反对派') '一个' '医生' ('survey', '调查') ('president', '总统')
#  ('use', '使用') ('animal', '动物') ('country', '国家') ('data', '数据')
#  ('organization', '组织') '可以' ('continue', '延续') ('syria', '叙利亚')
#  ('evidence', '证据') ('brain', '大脑')]
# Topic 16 :  [('economic', '经济') ('problem', '问题') ('europe', '欧洲') ('country', '国家')
#  ('crisis', '危机') '现在' '可能' ('world', '世界') ('greece', '希腊')
#  ('increase', '增长') ('eu', '欧盟') ('financial', '金融') ('past', '过去') '表示'
#  ('germany', '德国') '美国' ('france', '法国') ('policy', '政策') ('debt', '债务')
#  ('italy', '意大利') '面临' ('better', '更好') ('immigration', '移民')
#  ('growth', '增长速度') '影响' ('america', '全美') ('future', '未来')
#  ('japan', '日本') ('life', '生活') 'britain' ('business', '业务') '全球'
#  ('help', '帮助') ('hope', '希望') ('way', '途径') ('people', '人们') '继续' '发展'
#  ('spain', '西班牙') '欧元' ('bring', '带来') ('mr', '先生') ('rich', '丰富') '政治'
#  '承诺' ('effect', '作用') ('bank', '银行') ('long', '长期') ('right', '权利')
#  ('market', '市场')]
# Topic 17 :  ['second' ('number', '数目') '美国' ('language', '语言') ('minister', '部长')
#  ('english', '英语') ('mr', '先生') '一个' ('podcast', '播客')
#  ('government', '政府') ('european', '欧洲人') '来自' 'prime' ('president', '总统')
#  ('world', '世界') '英国' ('welcome', '欢迎') '还有' '报道' ('century', '世纪')
#  ('union', '工会') ('french', '法语') ('news', '新闻') '成为' ('party', '派对')
#  ('china', '中国') ('past', '过去') ('leader', '领导人') ('age', '年代')
#  ('europe', '欧洲') '美元' '公司' ('court', '法庭') ('greece', '希腊') '作为'
#  ('london', '伦敦') ('project', '项目') 'trial' ('british', '英国人')
#  ('france', '法国') ('health', '健康') ('city', '城市') ('korea', '韩国')
#  ('game', '比赛') 'episode' ('economic', '经济') '巨大' ('germany', '德国')
#  ('international', '国际') ('crisis', '危机')]
# Topic 18 :  ['可以' ('look', '看看') ('guide', '指导') ('website', '网站') ('learn', '学习')
#  ('english', '英语') 'learning' ('california', '加州') ('explanation', '解释')
#  ('information', '信息') '一个' ('complete', '完整') ('center', '中心') 'episode'
#  ('podcast', '播客') '不同' ('meaning', '意思') 'dr' ('like', '喜欢')
#  ('help', '帮助') ('download', '下载') 'los' ('couple', '夫妇') ('find', '发现')
#  'angeles' ('word', '单词') '看到' '还有' 'coming' ('include', '包括') '名字'
#  ('course', '课程') ('improve', '提高') ('use', '使用') ('host', '主持') '上面' '一种'
#  '中有' '东西' ('photo', '照片') ('today', '当今') ('store', '商店')
#  ('education', '教育') ('talk', '谈论') ('vocabulary', '词汇') ('day', '日子')
#  '一张' 'esl' '来自' ('newspaper', '报纸')]
# Topic 19 :  [('meaning', '意思') ('use', '使用') ('know', '知道') ('people', '人们')
#  ('expression', '表达') ('means', '手段') ('word', '单词') '一个' ('phrase', '短语')
#  '东西' ('want', '想要') '可以' ('thing', '事情') ('verb', '动词') ('person', '人士')
#  '时候' ('think', '认为') ('problem', '问题') '别人' ('like', '喜欢')
#  ('understand', '明白') ('change', '改变') '这样' '可能' ('tell', '告诉') '两个'
#  ('dialogue', '对话') ('good', '良好') ('mean', '意味着') '现在'
#  ('information', '信息') '一种' ('situation', '状况') ('need', '需要') '不会'
#  ('occur', '发生') 'saying' 'lot' ('talk', '谈论') ('common', '常见')
#  ('believe', '相信') ('right', '权利') ('help', '帮助') '没有' ('agree', '同意')
#  '不同' 'talking' ('hear', '听见') ('noun', '名词') ('note', '注意')]

# %%
def split_topics_by_languages(n_topic, n_words, model, corpus):
    source_topic_list = []
    target_topic_list = []
    for ti in range(n_topic):
        top_words = get_top_words(model.TW, corpus.reconcatenate_dict, ti, n_words=n_words)
        source_temp = []
        target_temp = []
        for word in top_words:
            if isinstance(word, tuple):
                source_temp.append(word[0])
                target_temp.append(word[1])
            elif isinstance(word, str):
                try:
                    word.encode("ascii")
                    source_temp.append(word)
                except UnicodeEncodeError:
                    target_temp.append(word)
        source_topic_list.append(source_temp)
        target_topic_list.append(target_temp)
    return source_topic_list, target_topic_list

# %%
source_topic_list, target_topic_list = split_topics_by_languages(n_topic=20, n_words=100,
                                                                 model=model, corpus=corpus)

# %%
corpus_file = "/home/ponshane/work_dir/CLTM/src/out/CLTM_Inputs/2018-12-19/selected50KDos.txt"
cooccurence_matrix, _, compound_dictionary, num_of_documents = documents_to_cooccurence_matrix(corpus_file,
                                                                                               is_pickle=False)
# Out:
# <class 'scipy.sparse.csc.csc_matrix'>
# (27673, 25000) (27673, 27673)

# %%
for each_top in range(5, 55, 5):
    c_s = coherence_score(cn_topic=target_topic_list, en_topic=source_topic_list,
                topk=each_top, cooccurence_matrix=cooccurence_matrix,
                compound_dictionary=compound_dictionary, num_of_documents=num_of_documents,
                coherence_method="npmi")
    j_s = avg_jaccard_similarity_between_topics(target_topic_list, source_topic_list, each_top)
    print(each_top, c_s, j_s)
# Out:
# 5 0.041470876278132444 0.015263157894736848
# 10 -0.02753921104196132 0.009210526315789478
# 15 -0.07723562105547122 0.007368421052631582
# 20 -0.10883361012970212 0.0061842105263157894
# 25 -0.12168628597710082 0.005368421052631581
# 30 -0.142465876496626 0.004736842105263162
# 35 -0.15651740657686633 0.0042857142857142825
# 40 -0.17582171465747526 0.00407894736842105
# 45 -0.18762349767385794 0.0036842105263157877
# 50 -0.19970412525621675 0.0034210526315789492
